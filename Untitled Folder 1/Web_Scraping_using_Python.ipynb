# %%
import bs4
from urllib.request import urlopen as uReq
import requests
import smtplib
import pandas as pd

my_url = "https://www.flipkart.com/search?q=lenovo+laptops&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_2_6_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_2_6_na_na_na&as-pos=2&as-type=RECENT&suggestionId=lenovo+laptops%7CLaptops&requestId=1d51cfbd-0efb-49cf-bc69-8f627f79019c&as-backfill=on"

uclient = uReq(my_url)
page_html = uclient.read()                                 # extracting data from website
uclient.close()
page_soup = bs4.BeautifulSoup(page_html, "html.parser")    # parses data to code

containers = page_soup.findAll("div", {"class": "_3O0U0u"})

print("Total items=", len(containers))


container = containers[0]


file = open("File4.csv", "w")
headers="ProductName,Price,Discount\n"
file.write(headers)

for container in containers:                                 # loop to check and print product details

    product_name = container.div.img["alt"]
    print("Name:", product_name)

    price = container.findAll("div", {"class": "_1vC4OE _2rQ-NK"})
    price_container = price[0].text.strip()                    # strip() eliminates unnecessary commas,spaces,etc
    price_container = price_container.replace("₹", "Rs.") 
    price_container = price_container.replace(",","")
    print("Price:", price_container)


    discount = container.findAll("div", {"class": "VGWI6T"})

    for discount_container in discount:
        discount_container = discount[0].text
        print("Discount:", discount_container)


    data = product_name + "," + price_container + ", " + discount_container + "\n"
    file.write(data)
    print("")

file.close()
# Out:
# Total items= 24
# Name: Lenovo Ideapad L340 Core i5 9th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA G...
# Price: Rs.60990
# Discount: 29% off
#
# Name: Lenovo IdeaPad Gaming 3i Core i7 10th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home/4 GB Graphics/NV...
# Price: Rs.77990
# Discount: 33% off
#
# Name: Lenovo Ideapad S145 Core i5 10th Gen - (8 GB/1 TB HDD/Windows 10 Home) 81W8 idea pad S145 -15IIL U Lap...
# Price: Rs.43990
# Discount: 32% off
#
# Name: Lenovo Ideapad S145 Ryzen 3 Dual Core - (4 GB/1 TB HDD/Windows 10 Home) S145-15API Thin and Light Lapt...
# Price: Rs.28990
# Discount: 20% off
#
# Name: Lenovo Ideapad 130 Core i3 7th Gen - (4 GB/1 TB HDD/DOS) 130-15IKB Laptop
# Price: Rs.25990
# Discount: 33% off
#
# Name: Lenovo Ideapad L340 Core i7 9th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA G...
# Price: Rs.71990
# Discount: 35% off
#
# Name: Lenovo Ideapad 130 APU Dual Core A9 - (4 GB/1 TB HDD/Windows 10 Home/2 GB Graphics) 130-15AST Laptop
# Name: Lenovo Ideapad 130 Core i5 8th Gen - (8 GB/1 TB HDD/DOS/2 GB Graphics) 130-15IKB Laptop
# Price: Rs.44990
# Discount: 26% off
#
# Name: Lenovo Ideapad S340 Core i3 10th Gen - (8 GB/1 TB HDD/Windows 10 Home) S340-14IIL Thin and Light Lapto...
# Price: Rs.37990
# Discount: 35% off
#
# Name: Lenovo Ideapad S145 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 10 Home) S145-15IIL Thin and Light Lap...
# Price: Rs.52990
# Discount: 13% off

# %%
def send_mail():

    #NOTE: Turn off 'Less Secure App Access' of the google account from you are going to send the mail.
    
    
    
    # creates SMTP session
    s = smtplib.SMTP('smtp.gmail.com', 587)

    # start TLS for security
    s.starttls()
    
    # Authentication
    s.login("sender_email_id", "sender_email_id_password")

    # message to be sent
    message = "Price for the product fell down"
    # sending the mail
    s.send_mail("sender_email_id", "receiver_email_id", message)

    # terminating the session
    s.quit()

# %%
df = pd.read_csv("File4.csv")
str = input('Enter the Price below you want products\nNote Enter only numerals')
threshold = int(str)

for i in df['Price']:
   
   if  int(i[3:])<=threshold:
    #You will get an error on the next line to resolve this error enter sender's email ID and password and 
    #Only enter receiver's email ID.
    send_mail()
    break;
# Out:
# Enter the Price below you want products
# Note Enter only numerals40000
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# <ipython-input-10-616d191a8fd4> in <module>
#       8     #You will get an error on the next line to resolve this error enter sender's email ID and password and
#       9     #Only enter receiver's email ID.
# ---> 10     send_mail()
#      11     break;
#
# <ipython-input-9-c75703c13535> in send_mail()
#      12
#      13     # Authentication
# ---> 14     s.login("sender_email_id", "sender_email_id_password")
#      15
#      16     # message to be sent
#
# D:\Anaconda\lib\smtplib.py in login(self, user, password, initial_response_ok)
#     728
#     729         # We could not login successfully.  Return result of last attempt.
# --> 730         raise last_exception
#     731
#     732     def starttls(self, keyfile=None, certfile=None, context=None):
#
# D:\Anaconda\lib\smtplib.py in login(self, user, password, initial_response_ok)
#     719                 (code, resp) = self.auth(
#     720                     authmethod, getattr(self, method_name),
# --> 721                     initial_response_ok=initial_response_ok)
#     722                 # 235 == 'Authentication successful'
#     723                 # 503 == 'Error: already authenticated'
#
# D:\Anaconda\lib\smtplib.py in auth(self, mechanism, authobject, initial_response_ok)
#     640         if code in (235, 503):
#     641             return (code, resp)
# --> 642         raise SMTPAuthenticationError(code, resp)
#     643
#     644     def auth_cram_md5(self, challenge=None):
#
# SMTPAuthenticationError: (535, b'5.7.8 Username and Password not accepted. Learn more at\n5.7.8  https://support.google.com/mail/?p=BadCredentials z9sm12604611pgh.94 - gsmtp')
