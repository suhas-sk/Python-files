# %%
import pandas as pd    #data handling
import numpy as np     #numerical computing
from matplotlib import pyplot as plt  #plotting graph
import seaborn as sns   #higher level pltting graph
#%matplotlib inline

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.isnull().count()   #no null values
# Out:
# id               21613
# date             21613
# price            21613
# bedrooms         21613
# bathrooms        21613
# sqft_living      21613
# sqft_lot         21613
# floors           21613
# waterfront       21613
# view             21613
# condition        21613
# grade            21613
# sqft_above       21613
# sqft_basement    21613
# yr_built         21613
# yr_renovated     21613
# zipcode          21613
# lat              21613
# long             21613
# sqft_living15    21613
# sqft_lot15       21613
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.isnull().values.any()  #No null values
# Out:
# False

# %%
rows,columns = df.shape

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
pd.set_option('display.float_format',lambda x: '%.2f' %x) 
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000 221900.00         3       1.00
# 1      6414100192  20141209T000000 538000.00         3       2.25
# 2      5631500400  20150225T000000 180000.00         2       1.00
# 3      2487200875  20141209T000000 604000.00         4       3.00
# 4      1954400510  20150218T000000 510000.00         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000 360000.00         3       2.50
# 21609  6600060120  20150223T000000 400000.00         4       2.50
# 21610  1523300141  20140623T000000 402101.00         2       0.75
# 21611   291310100  20150116T000000 400000.00         3       2.50
# 21612  1523300157  20141015T000000 325000.00         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650    1.00           0     0  ...      7
# ...

# %%
#pd.set_option('display.float_format',lambda x: '%.2f' %x)

# %%
pd.set_option('display.max_columns',21)   #setting column limit
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000 221900.00         3       1.00
# 1      6414100192  20141209T000000 538000.00         3       2.25
# 2      5631500400  20150225T000000 180000.00         2       1.00
# 3      2487200875  20141209T000000 604000.00         4       3.00
# 4      1954400510  20150218T000000 510000.00         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000 360000.00         3       2.50
# 21609  6600060120  20150223T000000 400000.00         4       2.50
# 21610  1523300141  20140623T000000 402101.00         2       0.75
# 21611   291310100  20150116T000000 400000.00         3       2.50
# 21612  1523300157  20141015T000000 325000.00         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 0             1180      5650    1.00           0     0          3      7
# ...

# %%
plt.scatter(df['sqft_living'],df['price'])
plt.axis([0,5000,0,500000])  #setting max and min limit of X,Y axes
# Out:
# [0, 5000, 0, 500000]

# %%
df2 = df[['sqft_living','price']]  #sqft-independent

# %%
df2
# Out:
#        sqft_living     price
# 0             1180 221900.00
# 1             2570 538000.00
# 2              770 180000.00
# 3             1960 604000.00
# 4             1680 510000.00
# ...            ...       ...
# 21608         1530 360000.00
# 21609         2310 400000.00
# 21610         1020 402101.00
# 21611         1600 400000.00
# 21612         1020 325000.00
#
# [21613 rows x 2 columns]

# %%
sns.jointplot('sqft_living','price',data = df2, xlim=(500,3500),ylim=(100000,1000000),height=10,alpha=0.7,marker = '*')
#xlim , ylim for setting limits
#aplha for transparency
#maker for symbol

# %%
df["zipcode"].nunique()   #zipcode is name of column . we are grouping
# Out:
# 70

# %%
df["zipcode"].value.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7fb4c7ed0011> in <module>
# ----> 1 df["zipcode"].value.count()
#
# NameError: name 'df' is not defined

# %%
df.groupby('zipcode')['price'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-dc6a7d0e82bc> in <module>
# ----> 1 df.groupby('zipcode')['price'].mean()
#
# NameError: name 'df' is not defined

# %%
sns.jointplot('sqft_living','price',data = df2[df["zipcode"]==98039],height=10,alpha=1,marker='+',color='black')

# %%
df_98039_new = df2[df['zipcode']==98039]

# %%
df_98039_new
# Out:
#        sqft_living      price
# 2974          4860 2950000.00
# 3761          4210 1905000.00
# 4077          1220  875000.00
# 4078          1220  940000.00
# 4149          7080 4000000.00
# 4411          9200 5570000.00
# 4791          1320  937500.00
# 5178          2680 1160000.00
# 5589          2620 1880000.00
# 5880          5450 3418800.00
# 6868          2870 1555000.00
# 7501          2640 1398000.00
# 8241          2680 1320000.00
# 9254          9890 6885000.00
# 9694          1530  865000.00
# 9809          2300 1000000.00
# 11278         3550 2100000.00
# 11952         4780 2575000.00
# 12295         2660 1712750.00
# 12811         1580  787500.00
# 13235         3640 1651000.00
# 13267         4460 1800000.00
# 13419         2950 1550000.00
# 13621         3060 1762000.00
# 13988         2740 1225000.00
# 14052         4430 2750000.00
# 14254         4150 1950000.00
# 14385         3570 2200000.00
# 14803         3110 1260000.00
# 15022         4670 2450000.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df_98039_new.describe()
# Out:
#        sqft_living      price
# count        50.00      50.00
# mean       3800.90 2160606.60
# std        1764.50 1166477.34
# min        1220.00  787500.00
# 25%        2680.00 1401000.00
# 50%        3560.00 1892500.00
# 75%        4452.50 2556250.00
# max        9890.00 6885000.00

# %%
df_98039_new.shape
# Out:
# (50, 2)

# %%
df_98039_new.to_csv('df_98039_new.csv',index=False)
